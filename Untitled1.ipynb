# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data=np.random.normal(0,1,(100))
# data

# %%
x_rang=list(range(100))
# color=['red','green']
theta = -1* np.pi * np.random.rand(100)
color=theta
r = 40*np.random.rand(100)

# %%
plt.scatter(x_rang,data,alpha=0.5,c=color,cmap='hsv',s=r**2)
